# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
import numpy as np

# %%
url = 'http://www.fullemployment.net/evi/3.0/SA2_profile_2016.php?SA2_code=124041467'

r = requests.get(url)
html = r.text

soup = BeautifulSoup(html)
table = soup.find('table', {"class": "table_list"})
rows = table.find_all('tr')
data = []
for row in rows[1:]:
    cols = row.find_all('td')
    cols = [ele.text.strip() for ele in cols]
    data.append([ele for ele in cols if ele])

result = pd.DataFrame(data)

# %%
from datetime import datetime, timedelta

#generated_dates = pd.date_range(datetime.today(), periods=5).tolist()

generated_dates = pd.date_range(start='10/2/2020', end = datetime.today() - timedelta(days=1)).tolist()

#generated_dates = pd.date_range(start='7/2/2020', end = datetime.today()).tolist()
dates = []
for date in generated_dates:
    new=date.strftime("%d-%B-%Y")
    if new[0] == '0':
        new = new[1:]
    dates.append(new)
    
print(dates)

dates[1]
# Out:
# ['2-October-2020', '3-October-2020', '4-October-2020', '5-October-2020', '6-October-2020', '7-October-2020', '8-October-2020', '9-October-2020', '10-October-2020', '11-October-2020', '12-October-2020', '13-October-2020', '14-October-2020', '15-October-2020', '16-October-2020', '17-October-2020', '18-October-2020', '19-October-2020', '20-October-2020', '21-October-2020', '22-October-2020', '23-October-2020', '24-October-2020', '25-October-2020', '26-October-2020', '27-October-2020', '28-October-2020', '29-October-2020', '30-October-2020', '31-October-2020', '1-November-2020', '2-November-2020', '3-November-2020', '4-November-2020', '5-November-2020', '6-November-2020', '7-November-2020', '8-November-2020', '9-November-2020', '10-November-2020', '11-November-2020', '12-November-2020', '13-November-2020', '14-November-2020', '15-November-2020', '16-November-2020', '17-November-2020']
# '3-October-2020'

# %%
generated_dates
# Out:
# [Timestamp('2020-10-02 00:00:00', freq='D'),
#  Timestamp('2020-10-03 00:00:00', freq='D'),
#  Timestamp('2020-10-04 00:00:00', freq='D'),
#  Timestamp('2020-10-05 00:00:00', freq='D'),
#  Timestamp('2020-10-06 00:00:00', freq='D'),
#  Timestamp('2020-10-07 00:00:00', freq='D'),
#  Timestamp('2020-10-08 00:00:00', freq='D'),
#  Timestamp('2020-10-09 00:00:00', freq='D'),
#  Timestamp('2020-10-10 00:00:00', freq='D'),
#  Timestamp('2020-10-11 00:00:00', freq='D'),
#  Timestamp('2020-10-12 00:00:00', freq='D')]

# %%
m = dates[1]
m
# Out:
# '3-October-2020'

# %%
url = 'https://www.dhhs.vic.gov.au/coronavirus-update-victoria-' + m.strftime("%A-%d-%B")
url
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-2fd4aa16cdf2> in <module>
# ----> 1 url = 'https://www.dhhs.vic.gov.au/coronavirus-update-victoria-' + m.strftime("%A-%d-%B")
#       2 url
#
# AttributeError: 'str' object has no attribute 'strftime'

# %%
url0 = 'https://www.dhhs.vic.gov.au/coronavirus-update-victoria-' + dates0[dates.index(date)]
url = url0[:-5]

# %%
url
# Out:
# 'https://www.dhhs.vic.gov.au/coronavirus-update-victoria-Sunday-18-October'

# %%
generated_dates = pd.date_range(start='11/7/2020', end = '11/8/2020').tolist()
dates = []
dates0 = []
for date in generated_dates:
    new=date.strftime("%d-%B-%Y")
    new0=date.strftime("%A-%d-%B-%Y")
    if new[0] == '0':
        new = new[1:]
    dates.append(new)
    dates0.append(new0)

for date in dates:
    n = 'https://www.dhhs.vic.gov.au/media-release-coronavirus-update-victoria-' + dates0[dates.index(date)]
    n = n.replace(n[-16], "", 1)

    print(n)
# Out:
# https://www.dhhs.vic.gov.au/media-release-coronavirus-update-victoria-Saturday-7-November-2020
# https://www.dhhs.vic.gov.au/media-release-coronavirus-update-victoria-Sunday-8-November-2020

# %%
generated_dates = pd.date_range(start='11/2/2020', end = datetime.today()-timedelta(days=1)).tolist()
#generated_dates = pd.date_range(start='11/7/2020', end = '11/11/2020').tolist()
dates = []
dates0 = []
for date in generated_dates:
    new=date.strftime("%d-%B-%Y")
    new0=date.strftime("%A-%d-%B-%Y")
    if new[0] == '0':
        new = new[1:]
    dates.append(new)
    dates0.append(new0)

confirmed = pd.DataFrame()
active = pd.DataFrame()
first = True

for date in dates:
    print("Starting to retrieve data for " + date)
    try: 
        url = 'https://www.dhhs.vic.gov.au/coronavirus-update-victoria-' + date

        r = requests.get(url)
        html = r.text

        soup = BeautifulSoup(html)
        table = soup.find('table')

        rows = table.find_all('tr')
    except:
        try:
            url = 'https://www.dhhs.vic.gov.au/coronavirus-update-victoria-' + str(0) + date 

            r = requests.get(url)
            html = r.text

            soup = BeautifulSoup(html)
            table = soup.find('table')

            rows = table.find_all('tr')
        except:
            try:
                url0 = 'https://www.dhhs.vic.gov.au/coronavirus-update-victoria-' + date 
                url = url0[:-5]

                r = requests.get(url)
                html = r.text

                soup = BeautifulSoup(html)
                table = soup.find('table')

                rows = table.find_all('tr')
            except:
                try:
                    url0 = 'https://www.dhhs.vic.gov.au/coronavirus-update-victoria-' + str(0) + date 
                    url = url0[:-5]

                    r = requests.get(url)
                    html = r.text

                    soup = BeautifulSoup(html)
                    table = soup.find('table')

                    rows = table.find_all('tr')
                except:
                    try:
                    
                        url = 'https://www.dhhs.vic.gov.au/coronavirus-update-for-victoria-' + dates0[dates.index(date)]
                        
                        r = requests.get(url)
                        html = r.text

                        soup = BeautifulSoup(html)
                        table = soup.find('table')

                        rows = table.find_all('tr')
                    except:
                        try:
                            url0 = 'https://www.dhhs.vic.gov.au/coronavirus-update-victoria-' + dates0[dates.index(date)]
                            url = url0[:-5]
                            r = requests.get(url)
                            html = r.text

                            soup = BeautifulSoup(html)
                            table = soup.find('table')

                            rows = table.find_all('tr')
                        except:
                            try:
                                url = 'https://www.dhhs.vic.gov.au/coronavirus-update-for-victoria-' + date
                                r = requests.get(url)
                                html = r.text
                                soup = BeautifulSoup(html)
                                table = soup.find('table')
                                rows = table.find_all('tr')
                            except:
                                try:
                                    url0 = 'https://www.dhhs.vic.gov.au/media-release-coronavirus-update-victoria-' + dates0[dates.index(date)]
                                    url = url0.replace(url0[-16], "", 1)
                                    r = requests.get(url)
                                    html = r.text
                                    soup = BeautifulSoup(html)
                                    table = soup.find('table')
                                    rows = table.find_all('tr')
                                except:
                                    try:
                                        url = 'https://www.dhhs.vic.gov.au/media-release-coronavirus-update-victoria-' + date
                                        r = requests.get(url)
                                        html = r.text
                                        soup = BeautifulSoup(html)
                                        table = soup.find('table')
                                        rows = table.find_all('tr')
                                    except:
                                        url0 = 'https://www.dhhs.vic.gov.au/media-release-coronavirus-update-victoria-' + date
                                        url = url0[:-5]
                                        r = requests.get(url)
                                        html = r.text
                                        soup = BeautifulSoup(html)
                                        table = soup.find('table')
                                        rows = table.find_all('tr')
                                    
                        
        
    data = []
    for row in rows[1:]:
        cols = row.find_all('td')
        cols = [ele.text.strip() for ele in cols]
        data.append([ele for ele in cols if ele])
    result = pd.DataFrame(data)
    
    confirmed_cases = result.drop([2], axis=1).T.head()
    active_cases = result.drop([1], axis=1).T.head()
    
    confirmed_cases.columns = confirmed_cases.iloc[0]
    confirmed_cases.drop(confirmed_cases.index[0], inplace = True)
    confirmed_cases.columns = confirmed_cases.columns.str.upper()
    confirmed_cases.rename(index={1: date}, inplace=True)
    confirmed_cases = confirmed_cases[['HUME', 'MELBOURNE', 'MELTON', 'MORELAND', 'MOONEE VALLEY', 'WYNDHAM', 'MOORABOOL','MACEDON RANGES', 'HOBSONS BAY','YARRA','MARIBYRNONG','DAREBIN','BRIMBANK','TOTAL']]
 #   cols_to_sum = df.columns[ : df.shape[1]-1]

    #confirmed_cases['NWMPHN Total']= confirmed_cases[confirmed_cases.columns[:confirmed_cases.shape[1]-1]].sum(axis=1)
    #confirmed_cases.sort_index(axis=1, inplace = True)
    confirmed = confirmed.append(confirmed_cases)
    

    active_cases.columns = active_cases.iloc[0]
    active_cases.drop(active_cases.index[0], inplace = True)
    active_cases.columns = active_cases.columns.str.upper()
    active_cases.rename(index={2: date}, inplace=True)
    active_cases = active_cases[['HUME', 'MELBOURNE', 'MELTON', 'MORELAND', 'MOONEE VALLEY', 'WYNDHAM', 'MOORABOOL','MACEDON RANGES', 'HOBSONS BAY','YARRA','MARIBYRNONG','DAREBIN','BRIMBANK', 'TOTAL']]
    #active_cases['NWMPHN Total']= active_cases[active_cases].sum(axis=1)
    #active_cases.sort_index(axis=1, inplace = True)
    active = active.append(active_cases)
    #print(active_cases)

cols = ['HUME', 'MELBOURNE', 'MELTON', 'MORELAND', 'MOONEE VALLEY', 'WYNDHAM', 'MOORABOOL','MACEDON RANGES', 'HOBSONS BAY','YARRA','MARIBYRNONG','DAREBIN','BRIMBANK']
confirmed[cols] = confirmed[cols].apply(pd.to_numeric, errors='coerce', axis=1)
confirmed['NWMPHN region']= confirmed[confirmed.columns[:confirmed.shape[1]-1]].sum(axis=1)
confirmed.rename(columns={'TOTAL':'VIC'}, inplace=True)

active[cols] = active[cols].apply(pd.to_numeric, errors='coerce', axis=1)
active['NWMPHN region']=active[active.columns[:active.shape[1]-1]].sum(axis=1)
active.rename(columns={'TOTAL': 'VIC'}, inplace=True)
confirmed
active
# Out:
# Starting to retrieve data for 2-November-2020
# Starting to retrieve data for 3-November-2020
# Starting to retrieve data for 4-November-2020
# Starting to retrieve data for 5-November-2020
# Starting to retrieve data for 6-November-2020
# Starting to retrieve data for 7-November-2020
# Starting to retrieve data for 8-November-2020
# Starting to retrieve data for 9-November-2020
# Starting to retrieve data for 10-November-2020
# Starting to retrieve data for 11-November-2020
# Starting to retrieve data for 12-November-2020
# Starting to retrieve data for 13-November-2020
# Starting to retrieve data for 14-November-2020
# Starting to retrieve data for 15-November-2020
# Starting to retrieve data for 16-November-2020
# Starting to retrieve data for 17-November-2020
# 0                 HUME  MELBOURNE  MELTON  MORELAND  MOONEE VALLEY  WYNDHAM  \
# 2-November-2020      4          1       5         1              0       10
# 3-November-2020      3          1       2         1              0        8
# 4-November-2020      2          1       2         1              0        6
# 5-November-2020      2          0       2         1              0        4
# 6-November-2020      2          0       2         0              0        3
# 7-November-2020      0          0       0         0              0        1
# 8-November-2020      0          0       0         0              0        0
# 9-November-2020      0          0       0         0              0        0
# 10-November-2020     0          0       0         0              0        0
# 11-November-2020     0          0       0         0              0        0
# 12-November-2020     0          0       0         0              0        0
# 13-November-2020     0          0       0         0              0        0
# 14-November-2020     0          0       0         0              0        0
# 15-November-2020     0          0       0         0              0        0
# 16-November-2020     0          0       0         0              0        0
# 17-November-2020     0          0       0         0              0        0
#
# 0                 MOORABOOL  MACEDON RANGES  HOBSONS BAY  YARRA  MARIBYRNONG  \
# 2-November-2020           0               0            2      1            0
# 3-November-2020           0               0            2      1            0
# 4-November-2020           0               0            1      1            0
# 5-November-2020           0               0            0      0            0
# 6-November-2020           0               0            0      0            0
# 7-November-2020           0               0            0      0            0
# 8-November-2020           0               0            0      0            0
# 9-November-2020           0               0            0      0            0
# 10-November-2020          0               0            0      0            0
# 11-November-2020          0               0            0      0            0
# 12-November-2020          0               0            0      0            0
# 13-November-2020          0               0            0      0            0
# 14-November-2020          0               0            0      0            0
# 15-November-2020          0               0            0      0            0
# 16-November-2020          0               0            0      0            0
# 17-November-2020          0               0            0      0            0
#
# 0                 DAREBIN  BRIMBANK VIC  NWMPHN region
# 2-November-2020         7         7  49             38
# 3-November-2020         4         6  38             28
# 4-November-2020         2         4  30             20
# 5-November-2020         0         2  20             11
# 6-November-2020         0         1  15              8
# 7-November-2020         0         1   8              2
# 8-November-2020         0         0   4              0
# 9-November-2020         0         0   4              0
# 10-November-2020        0         0   4              0
# 11-November-2020        0         0   4              0
# 12-November-2020        0         0   3              0
# 13-November-2020        0         0   3              0
# 14-November-2020        0         0   3              0
# 15-November-2020        0         0   3              0
# 16-November-2020        0         0   3              0
# 17-November-2020        0         0   3              0

# %%
confirmed
# Out:
# 0                 HUME  MELBOURNE  MELTON  MORELAND  MOONEE VALLEY  WYNDHAM  \
# 2-November-2020   1664        883    1155      1052            812     2264
# 3-November-2020   1664        883    1155      1052            812     2264
# 4-November-2020   1664        882    1155      1052            813     2265
# 5-November-2020   1663        884    1158      1052            813     2265
# 6-November-2020   1663        884    1158      1051            813     2265
# 7-November-2020   1661        885    1157      1050            813     2264
# 8-November-2020   1661        885    1157      1050            813     2265
# 9-November-2020   1661        888    1157      1049            814     2265
# 10-November-2020  1661        887    1156      1048            812     2264
# 11-November-2020  1662        894    1156      1047            810     2264
# 12-November-2020  1662        893    1157      1047            811     2264
# 13-November-2020  1662        893    1157      1047            811     2264
# 14-November-2020  1662        893    1157      1046            811     2265
# 15-November-2020  1662        893    1157      1047            811     2265
# 16-November-2020  1663        893    1157      1047            811     2265
# 17-November-2020  1663        893    1157      1047            810     2265
#
# 0                 MOORABOOL  MACEDON RANGES  HOBSONS BAY  YARRA  MARIBYRNONG  \
# 2-November-2020          38              57          505    462          595
# 3-November-2020          38              57          505    462          595
# 4-November-2020          38              57          505    463          595
# 5-November-2020          38              57          505    463          595
# 6-November-2020          38              57          505    463          596
# 7-November-2020          38              57          505    463          596
# 8-November-2020          38              57          505    463          596
# 9-November-2020          38              57          505    463          597
# 10-November-2020         38              57          506    463          598
# 11-November-2020         38              56          506    463          598
# 12-November-2020         38              56          506    463          598
# 13-November-2020         38              56          506    463          598
# 14-November-2020         38              56          506    463          598
# 15-November-2020         38              56          506    463          599
# 16-November-2020         38              56          506    463          599
# 17-November-2020         38              56          506    463          599
#
# 0                 DAREBIN  BRIMBANK    VIC  NWMPHN region
# 2-November-2020       667      2019  20345          12173
# 3-November-2020       667      2019  20345          12173
# 4-November-2020       667      2018  20345          12174
# 5-November-2020       668      2016  20345          12177
# 6-November-2020       668      2014  20345          12175
# 7-November-2020       668      2014  20345          12171
# 8-November-2020       669      2014  20345          12173
# 9-November-2020       669      2013  20345          12176
# 10-November-2020      669      2013  20345          12172
# 11-November-2020      667      2015  20345          12176
# 12-November-2020      667      2015  20345          12177
# 13-November-2020      667      2015  20345          12177
# 14-November-2020      667      2015  20345          12177
# 15-November-2020      667      2015  20345          12179
# 16-November-2020      667      2016  20345          12181
# 17-November-2020      667      2016  20345          12180

# %%
confirmed
# Out:
# 0                 HUME  MELBOURNE  MELTON  MORELAND  MOONEE VALLEY  WYNDHAM  \
# 2-November-2020   1664        883    1155      1052            812     2264
# 3-November-2020   1664        883    1155      1052            812     2264
# 4-November-2020   1664        882    1155      1052            813     2265
# 5-November-2020   1663        884    1158      1052            813     2265
# 6-November-2020   1663        884    1158      1051            813     2265
# 7-November-2020   1661        885    1157      1050            813     2264
# 8-November-2020   1661        885    1157      1050            813     2265
# 9-November-2020   1661        888    1157      1049            814     2265
# 10-November-2020  1661        887    1156      1048            812     2264
# 11-November-2020  1662        894    1156      1047            810     2264
# 12-November-2020  1662        893    1157      1047            811     2264
# 13-November-2020  1662        893    1157      1047            811     2264
# 14-November-2020  1662        893    1157      1046            811     2265
# 15-November-2020  1662        893    1157      1047            811     2265
# 16-November-2020  1663        893    1157      1047            811     2265
# 17-November-2020  1663        893    1157      1047            810     2265
#
# 0                 MOORABOOL  MACEDON RANGES  HOBSONS BAY  YARRA  MARIBYRNONG  \
# 2-November-2020          38              57          505    462          595
# 3-November-2020          38              57          505    462          595
# 4-November-2020          38              57          505    463          595
# 5-November-2020          38              57          505    463          595
# 6-November-2020          38              57          505    463          596
# 7-November-2020          38              57          505    463          596
# 8-November-2020          38              57          505    463          596
# 9-November-2020          38              57          505    463          597
# 10-November-2020         38              57          506    463          598
# 11-November-2020         38              56          506    463          598
# 12-November-2020         38              56          506    463          598
# 13-November-2020         38              56          506    463          598
# 14-November-2020         38              56          506    463          598
# 15-November-2020         38              56          506    463          599
# 16-November-2020         38              56          506    463          599
# 17-November-2020         38              56          506    463          599
#
# 0                 DAREBIN  BRIMBANK    VIC  NWMPHN region
# 2-November-2020       667      2019  20345          12173
# 3-November-2020       667      2019  20345          12173
# 4-November-2020       667      2018  20345          12174
# 5-November-2020       668      2016  20345          12177
# 6-November-2020       668      2014  20345          12175
# 7-November-2020       668      2014  20345          12171
# 8-November-2020       669      2014  20345          12173
# 9-November-2020       669      2013  20345          12176
# 10-November-2020      669      2013  20345          12172
# 11-November-2020      667      2015  20345          12176
# 12-November-2020      667      2015  20345          12177
# 13-November-2020      667      2015  20345          12177
# 14-November-2020      667      2015  20345          12177
# 15-November-2020      667      2015  20345          12179
# 16-November-2020      667      2016  20345          12181
# 17-November-2020      667      2016  20345          12180

# %%
from pandas import ExcelWriter

writer = ExcelWriter('test.xlsx')
all.to_excel(writer)
writer.save()

# %%
zones=pd.read_csv("zones.txt",delimiter="\t", header = None)

# %%
zones
# Out:
#                                               0
# 0                                Sydney">Sydney
# 1                          Melbourne">Melbourne
# 2                            Brisbane">Brisbane
# 3                            Adelaide">Adelaide
# 4                                  Perth">Perth
# ..                                          ...
# 99                         Devonport">Devonport
# 100                      Launceston">Launceston
# 101                      Ulverstone">Ulverstone
# 102                Alice Springs">Alice Springs
# 103  Canberra - Queanbeyan">Canberra-Queanbeyan
#
# [104 rows x 1 columns]

# %%
url = "http://www.fullemployment.net/evi/3.0/evi_3.0.php?SUA_Name_2016=Morisset+-+Cooranbong&order=1"
    
r = requests.get(url)
html = r.text

soup = BeautifulSoup(html)
table = soup.find('table')
rows = table.find_all('tr')
data = []
for row in rows[1:]:
    cols = row.find_all('td')
    cols = [ele.text.strip() for ele in cols]
    data.append([ele for ele in cols if ele])

result = pd.DataFrame(data) #table on the websitea

# %%
result = result[[0,2]]
result.columns=['SA2', 'EVI score']

# %%
result
# Out:
#                           SA2 EVI score
# 0  Bonnells Bay - Silverwater   0.26145
# 1       Morisset - Cooranbong   0.46206

# %%
df = pd.DataFrame()
for line in zones[0]:
    start = line.find(">",0,len(line))
    line = line[start+1:]
    #print(line)
    line = line.replace("-","+-+",1)
    #print(line)
    
    url = "http://www.fullemployment.net/evi/3.0/evi_3.0.php?SUA_Name_2016=" + line + "&order=1"
    
    r = requests.get(url)
    html = r.text

    soup = BeautifulSoup(html)
    table = soup.find('table')
    rows = table.find_all('tr')
    data = []
    for row in rows[1:]:
        cols = row.find_all('td')
        cols = [ele.text.strip() for ele in cols]
        data.append([ele for ele in cols if ele])

    final = pd.DataFrame(data) #table on the websitea
    
    df = df.append(final)
df
# Out:
#                                 0                      1         2  \
# 0   Bidwill - Hebersham - Emerton                 Sydney   1.07723
# 1   Greenfield Park - Prairiewood                 Sydney   1.16371
# 2                Fairfield - West                 Sydney   1.54497
# 3                       Fairfield                 Sydney   1.11460
# 4                    Edensor Park                 Sydney   1.24089
# ..                            ...                    ...       ...
# 95                          Crace  Canberra - Queanbeyan  -2.97551
# 96                          Forde  Canberra - Queanbeyan  -2.36818
# 97                       Franklin  Canberra - Queanbeyan  -2.14122
# 98                      Gungahlin  Canberra - Queanbeyan  -1.63462
# 99                         Turner  Canberra - Queanbeyan  -2.95155
#
#                3
# 0   View Profile
# 1   View Profile
# 2   View Profile
# 3   View Profile
# 4   View Profile
# ..           ...
# 95  View Profile
# 96  View Profile
# 97  View Profile
# 98  View Profile
# 99  View Profile
#
# [1801 rows x 4 columns]

# %%
df = df[[0,2]]
df.columns=['SA2', 'EVI score']

# %%
df
# Out:
#                               SA2 EVI score
# 0   Bidwill - Hebersham - Emerton   1.07723
# 1   Greenfield Park - Prairiewood   1.16371
# 2                Fairfield - West   1.54497
# 3                       Fairfield   1.11460
# 4                    Edensor Park   1.24089
# ..                            ...       ...
# 95                          Crace  -2.97551
# 96                          Forde  -2.36818
# 97                       Franklin  -2.14122
# 98                      Gungahlin  -1.63462
# 99                         Turner  -2.95155
#
# [1801 rows x 2 columns]

# %%
All_EVI = pd.merge(df, details, on='SA2', how='inner')

# %%
L_evi = pd.merge(df, details, on = 'SA2', how='left')
L_evi
# Out:
#                                 SA2 EVI score_x  \
# 0     Bidwill - Hebersham - Emerton     1.07723
# 1     Greenfield Park - Prairiewood     1.16371
# 2                  Fairfield - West     1.54497
# 3                         Fairfield     1.11460
# 4                      Edensor Park     1.24089
# ...                             ...         ...
# 1796                          Crace    -2.97551
# 1797                          Forde    -2.36818
# 1798                       Franklin    -2.14122
# 1799                      Gungahlin    -1.63462
# 1800                         Turner    -2.95155
#
#      % Employed in Accommodation, Cafes and Restaurants  \
# 0                                                 5.82%
# 1                                                 5.49%
# 2                                                 6.65%
# 3                                                 6.19%
# 4                                                 6.93%
# ...                                                 ...
# 1796                                              6.18%
# 1797                                              5.15%
# 1798                                              9.64%
# 1799                                              9.67%
# 1800                                              7.93%
#
#      % Employed in Construction % Employed in Finance and Insurance  \
# 0                         8.73%                               3.23%
# 1                        10.21%                               4.44%
# 2                        10.67%                               3.78%
# 3                        10.20%                               4.81%
# 4                        11.01%                               4.63%
# ...                         ...                                 ...
# 1796                      6.06%                               2.45%
# 1797                      6.49%                               1.73%
# 1798                      4.89%                               2.22%
# 1799                      6.48%                               1.42%
# 1800                      1.59%                               1.77%
#
#      % Employed in Manufacturing % Employed in Mining  \
# 0                         10.01%                0.05%
# 1                         11.97%                0.16%
# 2                         11.27%                0.17%
# 3                         10.32%                0.14%
# 4                         10.00%                0.12%
# ...                          ...                  ...
# 1796                       0.93%                0.00%
# 1797                       1.60%                0.22%
# 1798                       1.15%                0.00%
# 1799                       2.20%                0.00%
# 1800                       1.38%                0.00%
#
#      % Employed in Property and Business Services % Employed in Retail Trade  \
# 0                                           0.92%                     11.49%
# 1                                           1.31%                     11.01%
# 2                                           1.27%                     11.74%
# 3                                           1.09%                     10.46%
# 4                                           2.02%                     11.28%
# ...                                           ...                        ...
# 1796                                        1.44%                      5.87%
# 1797                                        1.51%                      7.27%
# 1798                                        1.48%                      8.43%
# 1799                                        0.99%                      8.86%
# 1800                                        1.42%                      5.30%
#
#      % without post secondary school qualifications  ...  \
# 0                                            57.09%  ...
# 1                                            52.57%  ...
# 2                                            55.13%  ...
# 3                                            52.91%  ...
# 4                                            51.87%  ...
# ...                                             ...  ...
# 1796                                         23.37%  ...
# 1797                                         28.47%  ...
# 1798                                         28.19%  ...
# 1799                                         31.60%  ...
# 1800                                         21.90%  ...
#
#      Median household income ($ per week)  \
# 0                                   $1067
# 1                                   $1430
# 2                                   $1203
# 3                                    $969
# 4                                   $1637
# ...                                   ...
# 1796                                $2486
# 1797                                $2944
# 1798                                $2114
# 1799                                $2066
# 1800                                $1924
#
#      Median individual income ($ per week)  \
# 0                                     $471
# 1                                     $445
# 2                                     $419
# 3                                     $395
# 4                                     $488
# ...                                    ...
# 1796                                 $1242
# 1797                                 $1327
# 1798                                 $1002
# 1799                                  $895
# 1800                                 $1125
#
#      Median mortgage repayment ($ per month) Median rent ($ per week)  \
# 0                                      $1528                     $265
# 1                                      $2000                     $420
# 2                                      $1950                     $410
# 3                                      $1625                     $350
# 4                                      $2000                     $425
# ...                                      ...                      ...
# 1796                                   $2500                     $380
# 1797                                   $2600                     $510
# 1798                                   $2000                     $373
# 1799                                   $2039                     $380
# 1800                                   $2015                     $400
#
#      Part-time employment as a % total             SA3  \
# 0                               30.14%    Mount Druitt
# 1                               31.10%       Fairfield
# 2                               32.61%       Fairfield
# 3                               31.71%       Fairfield
# 4                               31.30%       Fairfield
# ...                                ...             ...
# 1796                            22.04%       Gungahlin
# 1797                            24.03%       Gungahlin
# 1798                            24.44%       Gungahlin
# 1799                            25.70%       Gungahlin
# 1800                            25.37%  North Canberra
#
#                                SA4                         State  \
# 0               Sydney - Blacktown               New South Wales
# 1              Sydney - South West               New South Wales
# 2              Sydney - South West               New South Wales
# 3              Sydney - South West               New South Wales
# 4              Sydney - South West               New South Wales
# ...                            ...                           ...
# 1796  Australian Capital Territory  Australian Capital Territory
# 1797  Australian Capital Territory  Australian Capital Territory
# 1798  Australian Capital Territory  Australian Capital Territory
# 1799  Australian Capital Territory  Australian Capital Territory
# 1800  Australian Capital Territory  Australian Capital Territory
#
#      Total labour force participation rate Unemployment rate
# 0                                   52.86%            13.17%
# 1                                   52.56%             8.46%
# 2                                   49.20%            10.53%
# 3                                   44.27%            14.48%
# 4                                   58.63%             8.05%
# ...                                    ...               ...
# 1796                                82.12%             3.20%
# 1797                                82.82%             4.13%
# 1798                                79.74%             5.06%
# 1799                                76.86%             6.44%
# 1800                                73.61%             5.43%
#
# [1801 rows x 29 columns]

# %%
R_evi = pd.merge(df, details, on='SA2', how = 'right')
R_evi
# Out:
#                                 SA2 EVI score_x  \
# 0     Bidwill - Hebersham - Emerton     1.07723
# 1     Greenfield Park - Prairiewood     1.16371
# 2                  Fairfield - West     1.54497
# 3                         Fairfield     1.11460
# 4                      Edensor Park     1.24089
# ...                             ...         ...
# 1798                      Larapinta    -2.13288
# 1799                    Mount Johns    -2.58463
# 1800                           Ross    -1.08349
# 1801           Goolwa - Port Elliot         NaN
# 1802                  Victor Harbor         NaN
#
#      % Employed in Accommodation, Cafes and Restaurants  \
# 0                                                 5.82%
# 1                                                 5.49%
# 2                                                 6.65%
# 3                                                 6.19%
# 4                                                 6.93%
# ...                                                 ...
# 1798                                              5.30%
# 1799                                              7.66%
# 1800                                              7.41%
# 1801                                             10.11%
# 1802                                             10.32%
#
#      % Employed in Construction % Employed in Finance and Insurance  \
# 0                         8.73%                               3.23%
# 1                        10.21%                               4.44%
# 2                        10.67%                               3.78%
# 3                        10.20%                               4.81%
# 4                        11.01%                               4.63%
# ...                         ...                                 ...
# 1798                      8.11%                               0.59%
# 1799                      4.90%                               0.89%
# 1800                      9.57%                               0.28%
# 1801                     11.05%                               1.72%
# 1802                      9.90%                               1.70%
#
#      % Employed in Manufacturing % Employed in Mining  \
# 0                         10.01%                0.05%
# 1                         11.97%                0.16%
# 2                         11.27%                0.17%
# 3                         10.32%                0.14%
# 4                         10.00%                0.12%
# ...                          ...                  ...
# 1798                       1.86%                0.47%
# 1799                       1.12%                0.19%
# 1800                       3.00%                0.38%
# 1801                       5.83%                1.38%
# 1802                       4.29%                1.61%
#
#      % Employed in Property and Business Services % Employed in Retail Trade  \
# 0                                           0.92%                     11.49%
# 1                                           1.31%                     11.01%
# 2                                           1.27%                     11.74%
# 3                                           1.09%                     10.46%
# 4                                           2.02%                     11.28%
# ...                                           ...                        ...
# 1798                                        1.62%                      7.35%
# 1799                                        1.54%                      8.73%
# 1800                                        2.25%                      7.41%
# 1801                                        2.04%                     11.89%
# 1802                                        1.88%                     13.59%
#
#      % without post secondary school qualifications  ...  \
# 0                                            57.09%  ...
# 1                                            52.57%  ...
# 2                                            55.13%  ...
# 3                                            52.91%  ...
# 4                                            51.87%  ...
# ...                                             ...  ...
# 1798                                         34.01%  ...
# 1799                                         28.80%  ...
# 1800                                         36.90%  ...
# 1801                                         44.07%  ...
# 1802                                         45.79%  ...
#
#      Median household income ($ per week)  \
# 0                                   $1067
# 1                                   $1430
# 2                                   $1203
# 3                                    $969
# 4                                   $1637
# ...                                   ...
# 1798                                $2040
# 1799                                $2080
# 1800                                $1685
# 1801                                 $835
# 1802                                 $832
#
#      Median individual income ($ per week)  \
# 0                                     $471
# 1                                     $445
# 2                                     $419
# 3                                     $395
# 4                                     $488
# ...                                    ...
# 1798                                 $1059
# 1799                                 $1164
# 1800                                  $769
# 1801                                  $482
# 1802                                  $481
#
#      Median mortgage repayment ($ per month) Median rent ($ per week)  \
# 0                                      $1528                     $265
# 1                                      $2000                     $420
# 2                                      $1950                     $410
# 3                                      $1625                     $350
# 4                                      $2000                     $425
# ...                                      ...                      ...
# 1798                                   $2000                     $368
# 1799                                   $1842                     $331
# 1800                                   $2383                     $210
# 1801                                   $1213                     $250
# 1802                                   $1287                     $260
#
#      Part-time employment as a % total                         SA3  \
# 0                               30.14%                Mount Druitt
# 1                               31.10%                   Fairfield
# 2                               32.61%                   Fairfield
# 3                               31.71%                   Fairfield
# 4                               31.30%                   Fairfield
# ...                                ...                         ...
# 1798                            19.12%               Alice Springs
# 1799                            16.75%               Alice Springs
# 1800                            22.20%               Alice Springs
# 1801                            48.26%  Fleurieu - Kangaroo Island
# 1802                            48.99%  Fleurieu - Kangaroo Island
#
#                                SA4               State  \
# 0               Sydney - Blacktown     New South Wales
# 1              Sydney - South West     New South Wales
# 2              Sydney - South West     New South Wales
# 3              Sydney - South West     New South Wales
# 4              Sydney - South West     New South Wales
# ...                            ...                 ...
# 1798  Northern Territory - Outback  Northern Territory
# 1799  Northern Territory - Outback  Northern Territory
# 1800  Northern Territory - Outback  Northern Territory
# 1801  South Australia - South East     South Australia
# 1802  South Australia - South East     South Australia
#
#      Total labour force participation rate Unemployment rate
# 0                                   52.86%            13.17%
# 1                                   52.56%             8.46%
# 2                                   49.20%            10.53%
# 3                                   44.27%            14.48%
# 4                                   58.63%             8.05%
# ...                                    ...               ...
# 1798                                80.13%             2.88%
# 1799                                83.21%             2.27%
# 1800                                63.47%             3.68%
# 1801                                40.96%             7.16%
# 1802                                40.81%             7.29%
#
# [1803 rows x 29 columns]

# %%
df[df.SA2 == 'Victor Harbor']
# Out:
# Empty DataFrame
# Columns: [SA2, EVI score]
# Index: []

# %%
R_evi['EVI score_x'].isnull().sum()
# Out:
# 2

# %%
R_evi.isnull().sum()
# Out:
# SA2                                                   0
# EVI score_x                                           2
# % Employed in Accommodation, Cafes and Restaurants    0
# % Employed in Construction                            0
# % Employed in Finance and Insurance                   0
# % Employed in Manufacturing                           0
# % Employed in Mining                                  0
# % Employed in Property and Business Services          0
# % Employed in Retail Trade                            0
# % without post secondary school qualifications        0
# Average household size                                0
# EVI score_y                                           0
# Employment-Population ratio                           0
# Female labour force participation rate                0
# Female unemployment rate                              0
# Male labour force participation rate                  0
# Male unemployment rate                                0
# Median Age                                            0
# Median family income ($ per week)                     0
# Median household income ($ per week)                  0
# Median individual income ($ per week)                 0
# Median mortgage repayment ($ per month)               0
# Median rent ($ per week)                              0
# Part-time employment as a % total                     0
# SA3                                                   0
# SA4                                                   0
# State                                                 0
# Total labour force participation rate                 0
# Unemployment rate                                     0
# dtype: int64

# %%
All_EVI[All_EVI.SA2 == 'Victor Harbor']
# Out:
# Empty DataFrame
# Columns: [SA2, EVI score_x, % Employed in Accommodation, Cafes and Restaurants, % Employed in Construction, % Employed in Finance and Insurance, % Employed in Manufacturing, % Employed in Mining, % Employed in Property and Business Services, % Employed in Retail Trade, % without post secondary school qualifications, Average household size, EVI score_y, Employment-Population ratio, Female labour force participation rate, Female unemployment rate, Male labour force participation rate, Male unemployment rate, Median Age, Median family income ($ per week), Median household income ($ per week), Median individual income ($ per week), Median mortgage repayment ($ per month), Median rent ($ per week), Part-time employment as a % total, SA3, SA4, State, Total labour force participation rate, Unemployment rate]
# Index: []
#
# [0 rows x 29 columns]

# %%
writer = ExcelWriter('EVI.xlsx')
R_evi.to_excel(writer)
writer.save()
